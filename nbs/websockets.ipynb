# %%
import sys
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

# %%
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time

# Add the testing directory to the path
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

from vomeet_client.vomeet import parse_url,VomeetClient

# Cell 1: Imports
import websockets, httpx, json

from vomeet_client.vomeet import parse_url, VomeetClient

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = create_user_client(base_url=os.getenv('BASE_URL'),admin_api_key=os.getenv('ADMIN_API_TOKEN'))

# %%
# Google Meet:

meeting_url="https://meet.google.com/fov-ggxa-anx"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
#MS Teams:

meeting_url="https://teams.live.com/meet/9313542088192?p=FGfOc6hXyfj7UsDqW8"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
request_bot(client,platform, native_meeting_id, passcode=passcode, bot_name="Vomeet bot", language='en')
# Out:
# {'id': 151,
#  'user_id': 187,
#  'platform': 'google_meet',
#  'native_meeting_id': 'fov-ggxa-anx',
#  'constructed_meeting_url': 'https://meet.google.com/fov-ggxa-anx',
#  'status': 'requested',
#  'bot_container_id': '7f1eac2d02f93188e6b6cfd41323e21802acdb603afe4a5209dd6f120484f5c2',
#  'start_time': None,
#  'end_time': None,
#  'data': {},
#  'created_at': '2025-11-22T10:25:37.858224',
#  'updated_at': '2025-11-22T10:25:37.883815'}

# %%
import pandas as pd

# %%
msgs = []

# Cell 4: Connect WebSocket (runs until stopped)
async with websockets.connect(os.getenv('WS_URL'), additional_headers=[("X-API-Key", client._api_key)]) as ws:
    await ws.send(json.dumps({"action": "subscribe", "meetings": [{"platform": platform, "native_id": native_meeting_id}]}))
    
    async for frame in ws:
        msg = json.loads(frame)
        print(f"Received: {msg.get('type')}")
        msgs.append(msg)
        
        if msg['type'] == 'transcript.mutable':
            display(msg['payload']['segments'])
        else:
            print(msg)
# Out:
# Received: subscribed
# {'type': 'subscribed', 'meetings': [{'platform': 'google_meet', 'native_id': 'fov-ggxa-anx'}]}
# Received: meeting.status
# {'type': 'meeting.status', 'meeting': {'id': 151, 'platform': 'google_meet', 'native_id': 'fov-ggxa-anx'}, 'payload': {'status': 'joining'}, 'ts': '2025-11-22T10:25:41.790639'}
# Received: meeting.status
# {'type': 'meeting.status', 'meeting': {'id': 151, 'platform': 'google_meet', 'native_id': 'fov-ggxa-anx'}, 'payload': {'status': 'awaiting_admission'}, 'ts': '2025-11-22T10:25:53.254663'}
# Received: meeting.status
# {'type': 'meeting.status', 'meeting': {'id': 151, 'platform': 'google_meet', 'native_id': 'fov-ggxa-anx'}, 'payload': {'status': 'active'}, 'ts': '2025-11-22T10:25:57.415786'}
# Received: transcript.mutable
# [{'start': 0.0,
#   'text': ' You',
#   'end_time': 2.0,
#   'language': 'en',
#   'speaker': None,
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'NO_SPEAKER_EVENTS',
#   'absolute_start_time': '2025-11-22T10:25:57.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:25:59.505037+00:00'}]
# Received: transcript.mutable
# [{'start': 0.0,
#   'text': " So, this is what we're talking about.",
#   'end_time': 10.0,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:25:57.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:07.505037+00:00'},
#  {'start': 10.0,
#   'text': " We'll go to the end of the day.",
#   'end_time': 13.0,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:26:07.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:10.505037+00:00'}]
# Received: transcript.mutable
# [{'start': 10.0,
#   'text': " the other day, we'll go to the hospital and see you later.",
#   'end_time': 13.0,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:26:07.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:10.505037+00:00'}]
# Received: transcript.mutable
# [{'start': 10.0,
#   'text': ' The next day we will be able to see the whole screen.',
#   'end_time': 17.0,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:26:07.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:14.505037+00:00'},
#  {'start': 18.0,
#   'text': ' We will be able to see the whole screen.',
#   'end_time': 22.383,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:26:15.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:19.888037+00:00'}]
# Received: transcript.mutable
# [{'start': 17.0,
#   'text': ' Kyo-ta-ko-ei-mi-stru-in-ka-kon-ra-bo-t-t-n-i.',
#   'end_time': 23.0,
#   'language': 'en',
#   'speaker': 'Dmitriy Grankin',
#   'session_uid': 'aa8a650f-f831-4412-8428-95dd69719865',
#   'speaker_mapping_status': 'MAPPED',
#   'absolute_start_time': '2025-11-22T10:26:14.505037+00:00',
#   'absolute_end_time': '2025-11-22T10:26:20.505037+00:00'}]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[7], line 7
#       4 async with websockets.connect(os.getenv('WS_URL'), additional_headers=[("X-API-Key", client._api_key)]) as ws:
#       5     await ws.send(json.dumps({"action": "subscribe", "meetings": [{"platform": platform, "native_id": native_meeting_id}]}))
# ----> 7     async for frame in ws:
#       8         msg = json.loads(frame)
#       9         print(f"Received: {msg.get('type')}")
#
# File ~/miniconda3/envs/api_tests/lib/python3.13/site-packages/websockets/asyncio/connection.py:242, in Connection.__aiter__(self)
#     240 try:
#     241     while True:
# --> 242         yield await self.recv()
#     243 except ConnectionClosedOK:
#     244     return
#
# File ~/miniconda3/envs/api_tests/lib/python3.13/site-packages/websockets/asyncio/connection.py:303, in Connection.recv(self, decode)
#     256 """
#     257 Receive the next message.
#     258
#    (...)    300
#     301 """
#     302 try:
# --> 303     return await self.recv_messages.get(decode)
#     304 except EOFError:
#     305     pass
#
# File ~/miniconda3/envs/api_tests/lib/python3.13/site-packages/websockets/asyncio/messages.py:159, in Assembler.get(self, decode)
#     154 # Locking with get_in_progress prevents concurrent execution
#     155 # until get() fetches a complete message or is canceled.
#     157 try:
#     158     # First frame
# --> 159     frame = await self.frames.get(not self.closed)
#     160     self.maybe_resume()
#     161     assert frame.opcode is OP_TEXT or frame.opcode is OP_BINARY
#
# File ~/miniconda3/envs/api_tests/lib/python3.13/site-packages/websockets/asyncio/messages.py:51, in SimpleQueue.get(self, block)
#      49 self.get_waiter = self.loop.create_future()
#      50 try:
# ---> 51     await self.get_waiter
#      52 finally:
#      53     self.get_waiter.cancel()
#
# CancelledError:

# %%
client.stop_bot(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# {'message': 'Stop request accepted and is being processed.'}
